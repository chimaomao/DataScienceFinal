# %%
import pandas as pd
import numpy as np
import jieba

# %%
jobInfo = pd.read_csv('StudentJobPythonUTF8.csv',header=None, encoding='utf-8')

# %%
jobInfo
# Out:
#                                                     0   \
# 0                                                 職務名稱
# 1                       Back-end Web Developer 後端網頁工程師
# 2                                             多媒體研發工程師
# 3                                          人工智慧軟體應用工程師
# 4              Technical Support&Lab 技術支援軟體測試工程師(TSD2)
# 5                              軟體測試工程師/自動化測試工程師(ESSDD)
# 6                     Ethernet Switch 軟韌體開發工程師 (ESSDD)
# 7                    【RD】Software Engineer(中和)-TC18060
# 8                                            人工智能算法工程師
# 9                             後端工程師 (Backend Engineer)
# 10                          AI後端工程師 (Backend Engineer)
# 11                                     資訊專員(深耕計畫-專案助理)
# 12                                  陽明大學系合中心學士/碩士級研究助理
# 13                             資深人工智慧軟體工程師 (月薪12萬-30萬)
# 14                                人工智慧軟體工程師 (月薪8萬-20萬)
# 15                                           軟體工程師(高雄)
# ...

# %%
words = jieba.cut(jobInfo[0][5])

# %%
a = list(words)

# %%
a
# Out:
# ['軟體', '測試', '工程', '師', '/', '自動化', '測試', '工程', '師', '(', 'ESSDD', ')']
